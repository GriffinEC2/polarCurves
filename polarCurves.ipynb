# %%
import numpy as np
import matplotlib.pyplot as plt
pi = np.pi

# %%
theta = np.linspace(-pi, pi, 100)
r = abs(np.cos(theta))
#print(r)
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax.plot(theta, r)
ax.set_rticks([0, 0.5, 1, 1.25])
ax.set_rlabel_position(-22.5)
plt.show()

# %%
theta = np.linspace(0, 2*pi, 100)
a = 4
b = 3
c = 2
r = abs(a + b*np.sin(c*theta))
#print(r)
plt.polar(theta, r, color='blue', linewidth=2)
ax.set_rticks([0, 0.5, 1, 1.5, 2])
ax.set_rlabel_position(-22.5)
plt.show()

# %%
#1+2cosx is apple with tear-drop stem
#3-cosx is wierd egg thing
#1-2sinx is 1+2cosx rotated by -90 degs
#4+3sin2x is two eggs merged together at the top on the line theta=45 degs

# %%
theta = np.linspace(0, 2*pi, 100)
r = abs(np.cos(theta))
#print(r)
x = r * np.cos(theta)
y = r * np.sin(theta)
#print(x)
plt.plot(x,y)
plt.title("Polar Curve (Cartesian)", color='white', fontsize=14)


plt.xlabel("x", color = 'white')
plt.ylabel("y", color = 'white')
plt.tick_params(axis='both', colors='white')
